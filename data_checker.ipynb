# %%
import pandas as pd

# %%
df = pd.read_csv('training/ADAUSD/val.csv')

# %%
df.target.value_counts()
# Out:
# target
# 0    172931
# 1     15065
# 2      8310
# Name: count, dtype: int64

# %%
len(df)
# Out:
# 196306
