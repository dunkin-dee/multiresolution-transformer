# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from PyEMD import EMD

# %%
from working_data import clean_cols, clean_non_minute_rows, alt_label_df as label_df, normalize_by_window, split_df, add_bollinger_bands

# %%
df = pd.read_csv("data/GBPUSD/minutes.csv")[-10000:]
df = normalize_by_window(
    df, 
    window_size=1440, 
    normalizing_cols=[
        'close'
    ])

# %%
signal = np.array(df["close_normalized"].values)

# %%
emd = EMD()

# %%
imfs = emd.emd(signal, max_imf=8)

# %%
len(imfs)
# Out:
# 9

# %%
cur_num_imfs = imfs.shape[0]
num_imfs = 15

if cur_num_imfs < num_imfs:
    # Create a flat signal (array of zeros) with the same length as the original signal
    flat_signal = np.zeros_like(signal)
    
    # Append the required number of flat signals to imfs
    imfs = np.vstack([imfs] + [flat_signal] * (num_imfs - cur_num_imfs))

# %%
imfs.shape[0]
# Out:
# 15

# %%
imfs[0].max(), imfs[1].max(), imfs[2].max(), imfs[3].max(), imfs[4].max(), imfs[5].max()
# Out:
# (0.11963503657210323,
#  0.09572084875066653,
#  0.09260127202358819,
#  0.13002355276340194,
#  0.12224699975284495,
#  0.18100494919170285)

# %%
imfs[0].min(), imfs[1].min(), imfs[2].min(), imfs[3].min(), imfs[4].min(), imfs[5].min()
# Out:
# (-0.12004854755575545,
#  -0.08717412389655751,
#  -0.10205509424501594,
#  -0.12942415641394764,
#  -0.131648425966178,
#  -0.18757958657745896)

# %%
signal.min()
# Out:
# 0.0
